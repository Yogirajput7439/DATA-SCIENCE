# %%
a = input("Enter the name of your friend")
# Out:
# Enter the name of your friend yogesh rajput

# %%
b = input("enter the value of b ")
# Out:
# enter the value of b  34

# %%
c = input("enter the value of c ")
# Out:
# enter the value of c  23

# %%
a + b
# Out:
# 'yogesh rajput34'

# %%
b + c
# Out:
# '3423'

# %%
int (c) + int (b)
# Out:
# 57

# %%
result = 2 + 4 * 7

# %%
result
# Out:
# 30

# %%
result = ( 10 + 2 ) * 4

# %%
result
# Out:
# 48

# %%
result = 2 ** 3 ** 3

# %%
result
# Out:
# 134217728
