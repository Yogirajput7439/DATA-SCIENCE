# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("college_data.txt")

# %%
print(df)
# Out:
#            Sr No.            \tSeat                     Number \tPRN  \
# 1    \tNCAB020365  2024015200374904       \tAAKKA CHIMA PAWARA  \t08
# 2    \tNCAB020366  2024015200374885       \tAARTI SANTOSH RAUT  \t08
# 3    \tNCAB020367  2024015200376315  \tAARYANI INDRAJEET PARVE  \t08
# 4    \tNCAB020368  2024015200368745    \tADERAO ASMITA SUBHASH  \t08
# 5    \tNCAB020369  2024015200367966      \tADITYA BALU SATDIVE  \t08
# ..            ...               ...                        ...   ...
# 276  \tNCAB039777  2024015200720037       \tSHINDE JIVAN BABAN  \t08
# 277  \tNCAB039778  2024015200484424  \tSURAJ NANASAHEB KHATANE  \t08
# 278  \tNCAB039779  2024015200366093       \tTARPE VIKAS VASANT  \t08
# 279  \tNCAB039780  2024015200552926   \tVAIBHAV NAMDEV GAVHANE  \t08
# 280  \tNCAB039781  2024015200575813  \tVAIBHAV RAJENDRA THORAT  \t08
#
#         \tStudent Name                                   \tCollege Code  \
# ...
