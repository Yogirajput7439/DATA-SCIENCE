# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years, runs)
plt.show()

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]


plt.plot(years, kohli, color="red", linestyle="--", label="Virat Kohli")
plt.plot(years, sehwag, color="green", linewidth=3, linestyle="--", label="Virendar Sehwag")

plt.xlabel("Years")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend()

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
sharma = [0, 200, 900, 400, 500, 300, 600, 1200, 2050, 403, 220]

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]
sharma = [0, 200, 900, 1400, 1500, 1300, 1600, 1700, 2100, 2400]
plt.plot(years, kohli, linestyle="--",color="green", label="Virat kohli")
plt.plot(years, sehwag,linestyle="--",color="red", label="Virendar sehwag")
plt.plot(years, sharma,linestyle="--", color="yellow", label="Rohit sharma")
plt.legend()
plt.xlabel("Years")
plt.ylabel("Runs")
plt.title("Game Comparison")
plt.grid(True)
plt.tight_layout()
