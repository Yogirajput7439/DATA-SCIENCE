# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("marks_final.csv", na_values = ["AB"])

# %%
df
# Out:
#       SNO.  ROLL NUMBER Q1 (5)  Q2 (5)  Q3 (5)  Q4 (5)  Q5 (5)  Q6 (5)  \
# 0        1    102003733    NaN     NaN     NaN     NaN     NaN     NaN
# 1        2    102203002      5     NaN     4.0     4.0     4.0     4.0
# 2        3    102203003      5     4.0     4.0     4.0     4.0     5.0
# 3        4    102203005    NaN     NaN     NaN     NaN     3.0     5.0
# 4        5    102203007    NaN     NaN     NaN     5.0     4.0     3.0
# ...    ...          ...    ...     ...     ...     ...     ...     ...
# 1048  1049    102383062      5     4.0     NaN     5.0     3.0     4.0
# 1049  1050    102383067      5     2.0     3.0     4.0     3.0     5.0
# 1050  1051    102383071      5     3.0     5.0     4.0     3.0     3.0
# 1051  1052    102383081      5     3.0     3.0     NaN     4.0     NaN
# 1052  1053    102383083    NaN     NaN     3.0     NaN     5.0     NaN
#
#       Q7 (5)  Q8 (5)  Q9 (5)  Q10 (5)  Q11 (5)  Q12 (5)  Top 9 (out of 45)  \
# ...

# %%
avg1 = df['Top 9 (out of 45)']

# %%
np.mean(avg1)
# Out:
# 38.14434947768281

# %%
df.head()
# Out:
#    SNO.  ROLL NUMBER Q1 (5)  Q2 (5)  Q3 (5)  Q4 (5)  Q5 (5)  Q6 (5)  Q7 (5)  \
# 0     1    102003733    NaN     NaN     NaN     NaN     NaN     NaN     3.0
# 1     2    102203002      5     NaN     4.0     4.0     4.0     4.0     4.0
# 2     3    102203003      5     4.0     4.0     4.0     4.0     5.0     4.0
# 3     4    102203005    NaN     NaN     NaN     NaN     3.0     5.0     3.0
# 4     5    102203007    NaN     NaN     NaN     5.0     4.0     3.0     3.0
#
#    Q8 (5)  Q9 (5)  Q10 (5)  Q11 (5)  Q12 (5)  Top 9 (out of 45)  Out of 30
# 0     5.0     NaN      NaN      NaN      4.0                 12        8.0
# 1     3.0     5.0      5.0      5.0      3.0                 40       26.7
# 2     3.0     4.0      5.0      4.0      2.0                 39       26.0
# 3     4.0     4.0      5.0      5.0      NaN                 29       19.3
# 4     5.0     3.0      5.0      5.0      3.0                 36       24.0

# %%
notnull1 = df[('Q1 (5)').notnull()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 notnull1 = df[('Q1 (5)').notnull()]
#
# AttributeError: 'str' object has no attribute 'notnull'

# %%
mask = df['Q1 (5)'].notnull()
print(mask)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1048    True
# 1049    True
# 1050    True
# 1051    True
# 1052    True
# Name: Q1 (5), Length: 1053, dtype: bool

# %%
avg2 = df['Out of 30']

# %%
np.mean(avg2)
# Out:
# 25.430104463437797

# %%
gretter25 = df[df['Out of 30'] > 20 ]

# %%
gretter25
# Out:
#       SNO.  ROLL NUMBER Q1 (5) Q2 (5) Q3 (5) Q4 (5) Q5 (5) Q6 (5) Q7 (5)  \
# 1        2    102203002      5     AB      4      4      4      4      4
# 2        3    102203003      5      4      4      4      4      5      4
# 4        5    102203007     AB     AB     AB      5      4      3      3
# 5        6    102203008      3      3      5      4      1      4      3
# 6        7    102203012     AB      3      4      4      3      5      4
# ...    ...          ...    ...    ...    ...    ...    ...    ...    ...
# 1047  1048    102383059      2      2      4      5      5     AB      5
# 1048  1049    102383062      5      4     AB      5      3      4     AB
# 1049  1050    102383067      5      2      3      4      3      5      2
# 1050  1051    102383071      5      3      5      4      3      3      4
# 1051  1052    102383081      5      3      3     AB      4     AB     AB
#
#      Q8 (5) Q9 (5) Q10 (5) Q11 (5) Q12 (5)  Top 9 (out of 45)  Out of 30
# ...

# %%
sham1 = df['Q1 (5)']

# %%
df.fillna(df.mean(numeric_only=True))
# Out:
#       SNO.  ROLL NUMBER Q1 (5)    Q2 (5)    Q3 (5)    Q4 (5)   Q5 (5)  \
# 0        1    102003733    NaN  3.452747  4.099678  4.322234  3.26824
# 1        2    102203002      5  3.452747  4.000000  4.000000  4.00000
# 2        3    102203003      5  4.000000  4.000000  4.000000  4.00000
# 3        4    102203005    NaN  3.452747  4.099678  4.322234  3.00000
# 4        5    102203007    NaN  3.452747  4.099678  5.000000  4.00000
# ...    ...          ...    ...       ...       ...       ...      ...
# 1048  1049    102383062      5  4.000000  4.099678  5.000000  3.00000
# 1049  1050    102383067      5  2.000000  3.000000  4.000000  3.00000
# 1050  1051    102383071      5  3.000000  5.000000  4.000000  3.00000
# 1051  1052    102383081      5  3.000000  3.000000  4.322234  4.00000
# 1052  1053    102383083    NaN  3.452747  3.000000  4.322234  5.00000
#
#         Q6 (5)    Q7 (5)    Q8 (5)   Q9 (5)   Q10 (5)   Q11 (5)   Q12 (5)  \
# ...
